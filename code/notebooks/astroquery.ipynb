# %%
from astroquery.jplhorizons import Horizons

# %%
obj = Horizons(id='399',
               location='@sun',
               epochs={'start':'2010-01-01',
                       'stop':'2010-03-01',
                       'step':'1d'},
               id_type='smallbody')

# %%
eph = obj.ephemerides()

# %%
eph
# Out:
# <Table masked=True length=60>
#        targetname           datetime_str   datetime_jd ...  PABLon   PABLat
#           ---                   ---             d      ...   deg      deg
#          str24                 str17         float64   ... float64  float64
# ------------------------ ----------------- ----------- ... -------- -------
# 399 Persephone (1895 BP) 2010-Jan-01 00:00   2455197.5 ... 352.3013  1.3645
# 399 Persephone (1895 BP) 2010-Jan-02 00:00   2455198.5 ...  352.458  1.4008
# 399 Persephone (1895 BP) 2010-Jan-03 00:00   2455199.5 ... 352.6146   1.437
# 399 Persephone (1895 BP) 2010-Jan-04 00:00   2455200.5 ... 352.7713  1.4733
# 399 Persephone (1895 BP) 2010-Jan-05 00:00   2455201.5 ...  352.928  1.5095
# 399 Persephone (1895 BP) 2010-Jan-06 00:00   2455202.5 ... 353.0846  1.5458
# 399 Persephone (1895 BP) 2010-Jan-07 00:00   2455203.5 ... 353.2413   1.582
# 399 Persephone (1895 BP) 2010-Jan-08 00:00   2455204.5 ...  353.398  1.6182
# ...
